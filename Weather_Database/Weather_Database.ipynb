# %%
#Dependencies
import numpy as np  
from citipy import citipy 
import pandas as pd  
import pyowm
from pyowm.owm import OWM

# %%
#key
owm = OWM("5941710b62cb21bdfc3fb5bd8906d4fd") 
mgr= owm.weather_manager()

# %%
#Get the nearest city using the citipy module  
index = pd.Index(range(2000)) 
index
# Out:
# RangeIndex(start=0, stop=2000, step=1)

# %%
city = pd.Series(index=index, dtype=str)   
county = pd.Series(index=index, dtype=str) 
lats = pd.Series(index=index, dtype= np.float64)   
lngs = pd.Series(index=index, dtype= np.float64) 
max_temp = pd.Series(index=index, dtype= np.float64)
pct_humidity = pd.Series(index=index, dtype=int)  
pct_cloudy =  pd.Series(index=index, dtype=int)
wind_speed = pd.Series(index=index, dtype= np.float64)
current_description = pd.Series(index=index, dtype=str)

# %%
#create dataframe
df = pd.DataFrame({
    "City": city,
    "County":county,
    "Lat":lats,
    "Lng": lngs, 
    "Max Temp": max_temp, 
    "Humidity": pct_humidity, 
    "Cloudiness":pct_cloudy, 
    "Wind Speed":wind_speed, 
    "Current Description":current_description })
df
# Out:
#      City County  Lat  Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     NaN    NaN  NaN  NaN       NaN         0           0         NaN
# 1     NaN    NaN  NaN  NaN       NaN         0           0         NaN
# 2     NaN    NaN  NaN  NaN       NaN         0           0         NaN
# 3     NaN    NaN  NaN  NaN       NaN         0           0         NaN
# 4     NaN    NaN  NaN  NaN       NaN         0           0         NaN
# ...   ...    ...  ...  ...       ...       ...         ...         ...
# 1995  NaN    NaN  NaN  NaN       NaN         0           0         NaN
# 1996  NaN    NaN  NaN  NaN       NaN         0           0         NaN
# 1997  NaN    NaN  NaN  NaN       NaN         0           0         NaN
# 1998  NaN    NaN  NaN  NaN       NaN         0           0         NaN
# 1999  NaN    NaN  NaN  NaN       NaN         0           0         NaN
#
#      Current Description
# 0                    NaN
# 1                    NaN
# 2                    NaN
# ...

# %%
#Get latitudes and longitudes 
for i in range(df.shape[0]): 
    while True: 
        latitude = np.random.uniform(-90,90,1)[0] 
        longitude = np.random.uniform(-180,180,1)[0] 
        city = citipy.nearest_city(latitude,longitude) 
        try: 
            weather = mgr.weather_at_place("{},{}".format(city.city_name,city.country_code))   
        except pyowm.commons.exceptions.NotFoundError: 
            continue
        else: 
            break 
    lat = weather.location.lat
    long = weather.location.lon 
    max_temp = weather.weather.temperature('fahrenheit')['temp_max'] 
    humid = weather.weather.humidity 
    cloudy = weather.weather.clouds 
    wind_speed = weather.weather.wind(unit='miles_hour')['speed']  
    detail_status = weather.weather.detailed_status 
    df.iloc[i] = [city.city_name, city.country_code, lat, long, max_temp, humid, cloudy, wind_speed, detail_status]
# Out:
# 0 mulchen cl
# 1 yellowknife ca
# 2 krasnoselkup ru
# 3 tuatapere nz
# 4 thompson ca
# 5 sakleshpur in
# 6 chifeng cn
# 7 brae gb
# 8 ambon id
# 9 port hedland au
# 10 hermanus za
# 11 saskylakh ru
# 12 butaritari ki
# 13 shaoxing cn
# 14 contamana pe
# 15 punta arenas cl
# 16 busselton au
# 17 coromandel nz
# 18 bulancak tr
# 19 emerald au
# 20 souillac mu
# 21 pevek ru
# 22 carnarvon au
# 23 ushuaia ar
# 24 tiznit ma
# 25 cayenne gf
# 26 bengkulu id
# 27 barrow us
# 28 mahebourg mu
# 29 kyra ru
# 30 port blair in
# 31 segezha ru
# 32 sioux lookout ca
# 33 hobart au
# 34 cockburn town bs
# 35 aksu cn
# 36 los llanos de aridane es
# 37 hermanus za
# 38 kapaa us
# 39 bria cf
# 40 isangel vu
# 41 quelimane mz
# 42 atar mr
# 43 rawson ar
# 44 jamestown sh
# 45 karratha au
# 46 ust-omchug ru
# 47 kotovo ru
# 48 ushuaia ar
# 49 macaubas br
# 50 atuona pf
# 51 villa maria ar
# 52 rudnogorsk ru
# 53 odesskoye ru
# 54 avarua ck
# 55 thompson ca
# 56 vaini to
# 57 isangel vu
# ...

# %%
dir(pyowm.commons.exceptions.NotFoundError)

# %% [markdown]
# wr = mgr.weather_at_place("London,GB")
# wr

# %%
wr = mgr.weather_at_place("{},{}".format(citi.city_name,citi.country_code))

# %%
wr.location

# %%
wr.weather.humidity

# %%
wr.weather.temperature('fahrenheit')

# %%
dir(wr.weather)

# %%
wr.weather.clouds

# %%
wr.weather.wind(unit='miles_hour')['speed']

# %%
wr.weather.detailed_status

# %%
new_file = df.to_csv('df')
